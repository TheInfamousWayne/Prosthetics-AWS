# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = [16,10]

# %%
rewards = list(np.load("penalty.npy"))

# %%
plt.plot(rewards)

# %%
sum(rewards)
# Out:
# -177.23570897506414
