# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
rewards = pd.read_csv("train_rewards.csv", header=None)

# %%
plt.plot(aa)

# %%
a = []
for i in rewards.values[1:-3]:
    a.append(int(i[0]))

# %%
a.append(649)

# %%
rewards
# Out:
#                             0
# 0    <<<<<<< Updated upstream
# 1                         494
# 2                         515
# 3                         513
# 4                         510
# 5                         546
# 6                         501
# 7                         505
# 8                         506
# 9                         508
# 10                        520
# 11                        503
# 12                        495
# 13                        494
# 14                        515
# 15                        471
# 16                        546
# 17                        494
# 18                        500
# 19                        503
# 20                        510
# 21                        522
# 22                        533
# 23                        512
# 24                        505
# 25                        512
# 26                        514
# 27                        562
# 28                        512
# 29                        527
# ...

# %%
a
# Out:
# [494,
#  515,
#  513,
#  510,
#  546,
#  501,
#  505,
#  506,
#  508,
#  520,
#  503,
#  495,
#  494,
#  515,
#  471,
#  546,
#  494,
#  500,
#  503,
#  510,
#  522,
#  533,
#  512,
#  505,
#  512,
#  514,
#  562,
#  512,
#  527,
#  505,
#  507,
#  521,
#  524,
#  501,
#  507,
#  530,
#  505,
#  523,
#  532,
#  490,
#  490,
#  504,
#  527,
#  534,
#  520,
#  518,
#  562,
#  605,
#  615,
#  653,
#  660,
#  667,
#  617,
#  596,
#  583,
#  604,
#  590,
#  599,
#  714,
#  636,
#  576,
#  600,
#  579,
#  637,
#  623,
#  607,
#  574,
#  607,
#  582,
#  607,
#  610,
#  611,
#  571,
#  594,
#  592,
#  582,
#  557,
#  610,
#  622,
#  633,
#  559,
#  620,
#  602,
#  624,
#  581,
#  600,
#  618,
#  572,
#  584,
#  560,
#  575,
#  577,
#  599,
#  610,
#  603,
#  594,
#  609,
#  599,
#  576,
#  586,
#  679,
#  610,
#  621,
#  599,
#  596,
#  584,
#  623,
#  584,
#  544,
#  593,
#  606,
#  588,
#  573,
#  635,
#  588,
#  636,
#  594,
#  630,
#  575,
#  662,
#  564,
#  575,
#  604,
#  605,
#  602,
# ...

# %%
np.save('ave_rewards.npy',a)

# %%
aa = list(np.load("train_rewards.npy"))

# %%
aa
# Out:
# [1.4, 2.2]

# %%
a = [1.4,2.2]

# %%
a
# Out:
# [1.4, 2.2]
